# %%
light="green"
if light=="red":
    ptint("stop")
elif light=="green":
    print("go")
# Out:
# go

# %%
marks=80
if marks>=90:
    print("grade is A")
elif 90>marks>=80:
    print("grade is B")
elif 80>marks>=70:
    print("grade is C")
elif 70>marks:
    print("grade is C")
# Out:
# grade is B

# %%
num =int(input("Enter a number"))
if num%2==0:
    
    print("even")
else:
    print("odd")
# Out:
# Enter a number 7
# odd

# %%
if num*7:
    print("yes")
else:
    print("not")
# Out:
# yes

# %%
a =int(input("Enter first number"))
b=int(input("Enter second number"))
c=int(input("Enter third number"))
if a>b and a>c:
    print(" a is gratar then three")
elif b>c:
    print("b is grater then three")
else:
    print("c is grater then three")
# Out:
# Enter first number 20
# Enter second number 30
# Enter third number 40
# c is grater then three

# %%
num =int(input("Enter a number"))
if num%7==0:
    print("multipul of 7")
else:
    print("not")
# Out:
# Enter a number 28
# multipul of 7
