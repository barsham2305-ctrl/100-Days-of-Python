# %% [markdown]
# #### Write a program that asks for the user’s first name and last name, then prints:

# %%
first_name = input("Enter Your First Name:")
last_name = input ("Enter Your last Name:")
print(f"Hello {first_name} {last_name}!")
# Out:
# Enter Your First Name: Barsha
# Enter Your last Name: Mandal
# Hello Barsha Mandal!

# %% [markdown]
# #### Ask the user for their age, then print how many months old they are.

# %%
age = int(input("Enter your age:"))
months = age * 12

print(f" your {months} monthes old.")
# Out:
# Enter your age: 19
#  your 228 monthes old.

# %% [markdown]
# #### Simple Calculator
#
# ***Ask the user for two numbers and print:***
#
# *Their sum*
#
# *Their difference*
#
# *Their product*
#
# *Their quotient*

# %%
num1 = float(input("Enter first number"))
num2 = float(input("Enter second number"))

sum_result = num1 + num2
difference = num1 - num2
product    = num1 * num2
quotient   = num1 / num2

print(f"sum {sum_result}")
print(f"difference {difference}")
print(f"quotient {quotient}")
# Out:
# Enter first number 30
# Enter second number 60
# sum 90.0
# difference -30.0
# quotient 0.5

# %% [markdown]
# #### Area of a Rectangle
#
# ***Ask for the length and width, then print the area.***

# %%
length = float(input("Enter the length"))
width = float(input("Enter the width"))

area = length * width

print(f" The area of the rectangle  is {area}")
# Out:
# Enter the length 153
# Enter the width 46
#  The area of the rectangle  is 7038.0

# %% [markdown]
# #### Last Digit of a Number
#
# ***Ask the user for a number and print its last digit.***

# %%
number =int(input("Enter a number:"))

last_digit = number % 10

print(f"The last digit is {last_digit}")
# Out:
# Enter a number: 567
# The last digit is 7

# %% [markdown]
# #### Even or Odd
#
# **Ask the user for a number and print whether it's even or odd.**

# %%
num =int(input("Enter a number"))

if number % 2 == 0:
    print("The number is even.")
else:
    print("The number is odd")
# Out:
# Enter a number 8
# The number is odd
