# %%
dict={'Name':'Barsha','age':19}

# %%
dict['city']='Delhi'

# %%
dict
# Out:
# {'Name': 'Barsha', 'age': 19, 'city': 'Delhi'}

# %%
student={"name":"barsha",
         "score":{
             "chem":98,
             "phy":97,
             "math":95
         }
        }

# %%
student
# Out:
# {'name': 'barsha', 'score': {'chem': 98, 'phy': 97, 'math': 95}}

# %%
student.keys()
# Out:
# dict_keys(['name', 'score'])

# %%
student.values()
# Out:
# dict_values(['barsha', {'chem': 98, 'phy': 97, 'math': 95}])

# %%
student.items()
# Out:
# dict_items([('name', 'barsha'), ('score', {'chem': 98, 'phy': 97, 'math': 95})])

# %%
print(student.get('name'))
# Out:
# barsha

# %%
student['city']='Delhi'

# %%
student.update({'phone':123432123})

# %%
student
# Out:
# {'name': 'barsha',
#  'score': {'chem': 98, 'phy': 97, 'math': 95},
#  'city': 'Delhi',
#  'phone': 123432123}

# %%
collection={1,2,3,4,4,6,6}

# %%
print(type(collection))
# Out:
# <class 'set'>

# %%
collection
# Out:
# {1, 2, 3, 4, 6}

# %%
print(len(collection))
# Out:
# 5

# %%
print(type(set))
# Out:
# <class 'set'>

# %%
set.add('barsha')

# %%
set
# Out:
# {'barsha'}

# %%
set1={1,2,3,3}

# %%
set2={4,5,6,6}

# %%
set1.union(set2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
table={"cat":"animal",
       "table":["varsha","mandal"]}

# %%
student={"python","java","c++","c++","c","python"}  #total number of classroom 
print(len(student))
# Out:
# 4

# %%
x=int(input("Enter a number"))
y=int(input("Enter number"))
z=int(input("Enter number"))
dict={}
dict.update({'maths':x})
dict.update({'chem':y})
dict.update({'science':z})
# Out:
# Enter a number 89
# Enter number 99
# Enter number 90

# %%
dict
# Out:
# {'maths': 89, 'chem': 99, 'science': 90}

# %%
print(x)
# Out:
# 89
