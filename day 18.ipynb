# %%
a= 1

# %%
def calc_sum(a,b):
    sum=a+b
    print(sum)

# %%
calc_sum(2,10)
# Out:
# 12

# %%
def print_():
    print("hello")

# %%
print_()
# Out:
# hello

# %%
def avg(a,b,c,d):
    x=a+b+c+d
    avge=x/4
    print(avge)

# %%
avg(11,22,44,66)
# Out:
# 35.75

# %%
print("hello", end=" ")
print("Barsha")
# Out:
# hello Barsha
