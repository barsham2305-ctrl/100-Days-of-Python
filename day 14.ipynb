# %%
a = 1,2,3,4,5,5,6,7,8

# %%
b=a[0:7]

# %%
b
# Out:
# (1, 2, 3, 4, 5, 5, 6)

# %%
n=0
for i in range(1,6):
    n = n+i
    print(n)
# Out:
# 1
# 3
# 6
# 10
# 15

# %%
str1= "my name is barsha.\t I M form westbengal"
print(str1)
# Out:
# my name is barsha.	 I M form westbengal

# %%
str1 = "my name is barsha.\n I M from westbengal"
print(str1)
# Out:
# my name is barsha.
#  I M from westbengal

# %%
print(len(str1))
# Out:
# 39

# %%
str_="apna"
str2 = "college"
len1=str_+ " " + str2
print(len(len1))
# Out:
# 12

# %%
str1="apna college"
ch = str1[0]
print(ch)
# Out:
# a

# %%
nam="barsha"
b=nam[1:3]
print(b)
# Out:
# ar

# %%
print(nam[-3:-1])
# Out:
# sh

# %%
list1 = [10, 20, 30, 40, 50]

start = 1
end = 4

result = []
for i in range(start, end):
    result.append(list1[i])

print(result)
# Out:
# [20, 30, 40]

# %%
str1="i am studing in apna college"  #returns true if string endswith substr
print(str1.endswith("ege"))
# Out:
# True

# %%
print(str1.capitalize())
# Out:
# I am studing in apna college

# %%
str1
# Out:
# 'I am studing in apna college'

# %%
print(str1)
# Out:
# I am studing in apna college

# %%
str = "I am studing in apna college"
print(str.replace("o","a"))
# Out:
# I am studing in apna callege

# %%
name="barsha"
print(name.find("a"))
# Out:
# 1

# %%
print(str.count('i'))
# Out:
# 2

# %%
print(len(name))
# Out:
# 6

# %%
str2=input("first nam")
print(len(str2))
# Out:
# first nam barsha
# 6

# %%
print(name.count("h"))
# Out:
# 4
