# %%
x = 'welcome'
print(x[3:5])
# Out:
# co

# %%
x = 'welcome'
print(x[3:])
# Out:
# come

# %%
num = 7
print(num ** 2)
# Out:
# 49

# %%
n = 15
if n % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Odd

# %%
fruits = ["apple", "banana", "mango"]
for f in fruits:
    print(f)
# Out:
# apple
# banana
# mango

# %%
nums = [3, 17, 10, 25, 8]
count = 0
for n in nums:
    if n > 10:
        count += 1
print(count)
# Out:
# 2

# %%
text = "python"
print(text[::-1])
# Out:
# nohtyp

# %%
numbers = [10, 45, 32, 99, 4]
print(max(numbers))
# Out:
# 99

# %%
sentence = "I love Java"
print(sentence.replace("Java", "Python"))
# Out:
# I love Python

# %%
student = {"name": "Aisha", "age": 18}
print(student["age"])
# Out:
# 18

# %%
i = 5
while i > 0:
    print(i)
    i -= 1
# Out:
# 5
# 4
# 3
# 2
# 1
