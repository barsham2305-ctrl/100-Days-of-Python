# %% [markdown]
# #### Ask the user for their name and print a greeting.

# %%
name=input('name')
# Out:
# name Barsha

# %% [markdown]
# #### Ask the user for two numbers and print their sum.

# %%
num1=float(input("Enter first number"))
num2=float(input("Enter second number"))
sum_number= num1+num2
print("The sum is:",sum_number)
# Out:
# Enter first number 5
# Enter second number 2
# The sum is: 7.0

# %% [markdown]
# #### Ask the user for their age and print how old they will be after 10 years.

# %%
age= int(input("enter your age"))
future_age = age + 10
print("after 10 years,you will be",future_age,"years old.")
# Out:
# enter your age 19
# after 10 years,you will be 29 years old.

# %% [markdown]
# #### Ask the user for a number and print its square.

# %%
num= float(input("Enter a number"))
square = num*num
print("The square of the number is ",square)
# Out:
# Enter a number 2
# The square of the number is  4.0

# %% [markdown]
# #### Ask the user for a string and print it in reverse.

# %%
text = input("Enter a string")
reverse_text = text[::-1]
print("Reversed String",reverse_text)
# Out:
# Enter a string python
# Reversed String nohtyp

# %% [markdown]
# #### Ask the user for their city and country and print a formatted message:

# %%
city= input("Enter your city")
country = input("Enter your country")
print(f"you live in {city},{country}.")
# Out:
# Enter your city Kolkata
# Enter your country India
# you live in Kolkata,India.
