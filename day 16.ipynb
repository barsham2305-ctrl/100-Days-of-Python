# %%
# string are inmutable, that's why string values can't be changed 
# but list can be changed because list are mutable

# %%
student=["kajal",88,19,"delhi"]
student[0]="barsha"
print(student)
# Out:
# ['barsha', 88, 19, 'delhi']

# %%
type(student)
# Out:
# list

# %%
marks=[69,77,80,91,92,89]

# %%
marks[1:4]
# Out:
# [77, 80, 91]

# %%
marks.append(77)

# %%
print(marks)
# Out:
# [69, 77, 80, 91, 92, 89, 77]

# %%
#marks.sort()

# %%
marks
# Out:
# [69, 77, 77, 80, 89, 91, 92]

# %%
marks.reverse()

# %%
marks
# Out:
# [89, 92, 91, 80, 77, 69]

# %%
marks[::-1]
# Out:
# [92, 91, 89, 80, 77, 77, 69]

# %%
list =['a','r','e','f','y','t']
list.reverse()

# %%
list
# Out:
# ['t', 'y', 'f', 'e', 'r', 'a']

# %%
marks.insert(2,45)

# %%
list.pop(2)
# Out:
# 'f'

# %%
list
# Out:
# ['t', 'y', 'e', 'r', 'a']

# %%
marks.remove(77)

# %%
marks
# Out:
# [69, 45, 77, 80, 89, 91, 92]

# %%
tuple=(11,22,33,44,44)

# %%
tuple[1]
# Out:
# 22

# %%
tuple.index(22)
# Out:
# 1

# %%
tuple.count(44)
# Out:
# 2

# %%
moves=[]
a=input("Enter one move name")
b=input("Enter two move name")
c=input("Enter three move name")
moves.append(a)
moves.append(b)
moves.append(c)
# Out:
# Enter one move name meet jao black
# Enter two move name back to the futher
# Enter three move name 96

# %%
moves
# Out:
# ['meet jao black', 'back to the futher', '96']

# %%
list=[1,2,3,2,1]
list.reverse()

# %%
list
# Out:
# [1, 2, 3, 2, 1]

# %%
list=["maam"]
list.reverse()
list
# Out:
# ['maam']

# %%
grade=["A","B","A","C","A","B"]

grade.count("A")
# Out:
# 3

# %%
grade.sort()

# %%
grade=[]
