# %%
fruits = ["apple","banana","cherry"]
a,b,c = fruits
print(b)
# Out:
# banana

# %%
print("Hello","world")
# Out:
# Hello world

# %%
a = 'Hello'
b = 'python'
print(a + b)
# Out:
# Hellopython

# %%
a =4
b=5
print(a+b)
# Out:
# 9

# %%
x = 'awesome'
def myfunc():
    x = 'fantastic'
myfunc()
print('python is ' + x)
# Out:
# python is awesome

# %%
x = 'awesome'
def myfunc():
    global x
    x = 'fantastic'
myfunc()
print('python is ' + x)
# Out:
# python is fantastic

# %%
a = 5

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(fruits))
# Out:
# <class 'list'>

# %%
x ={'Name': 'Barsha','age':19}

# %%
print(type(x))
# Out:
# <class 'dict'>

# %%
x = 'welcome'
print(x[3])
# Out:
# c

# %%
x = 'hello','world'
print(len(x))
# Out:
# 2

# %%
txt = 'Hello','World'
x = txt[0]
print(x)
# Out:
# Hello
